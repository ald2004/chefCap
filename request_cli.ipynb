# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import base64
from io import BytesIO
# %matplotlib inline
# %matplotlib notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
with open('test_xzj_head_bin','rb') as fid:
    xzj_bin=fid.read()
    xzj_array=np.frombuffer(xzj_bin,dtype=np.float32).reshape(256,256,3)
    imshow(xzj_array)

# %%
#importing the requests library
import base64
import requests
# %pylab inline 
import json
from io import BytesIO
from tensorflow.keras.preprocessing import image
# defining the api-endpoint
API_ENDPOINT = "http://10.1.202.11:5000/makeup/"
image_path = 'imgs/no_makeup/'
image_path +='xzj_head.jpg'
b64_image = ""
# Encoding the JPG,PNG,etc. image to base64 format
with open(image_path, "rb") as imageFile:
    b64_image = base64.b64encode(imageFile.read())

# data to be sent to api
data = {'IMG_BASE64': b64_image}

# sending post request and saving response as response object
r = requests.post(url=API_ENDPOINT, data=data)

# extracting the response
imshow((image.load_img(BytesIO(base64.b64decode(json.loads(r.text)['predictions']['IMAGE'])))))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/yuanpu/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/yuanpu/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/yuanpu/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
tmpstr_bin=b'...'
tmpstr_decode=base64.b64decode(tmpstr_bin)
makeup_bin = b"..."
makeup = image.img_to_array(image.load_img(BytesIO(base64.b64decode(tmpstr_bin))))

# %%
#importing the requests library
import base64
import requests
# %pylab inline
import json
from io import BytesIO
from tensorflow.keras.preprocessing import image
# defining the api-endpoint
API_ENDPOINT = "http://10.1.202.11:5000/kitchen"
image_path = 'imgs/no_makeup/'
image_path +='644.png'
b64_image = ""
# Encoding the JPG,PNG,etc. image to base64 format
with open(image_path, "rb") as imageFile:
    b64_image = base64.b64encode(imageFile.read())

# data to be sent to api
data = {'IMG_BASE64': "xx"}

# sending post request and saving response as response object
r = requests.post(url=API_ENDPOINT, json=json.dumps(data))

# extracting the response
# imshow((image.load_img(BytesIO(base64.b64decode(json.loads(r.text)['predictions']['IMAGE'])))))
r.text
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ...

# %%
from json import dumps
image_path = '/home/yuanpu/chefCap/data/val/JPEGImages/'
image_path +='mq291bb92e000113-175437.jpg'
API_ENDPOINT = "http://10.1.202.11:5000/kitchen"

with open(image_path, "rb") as imageFile:
    base64_bytes = base64.b64encode(imageFile.read())
base64_string = base64_bytes.decode('utf-8')
raw_data = {'IMG_BASE64': base64_string,'SCORE_THRES': 0.7}

response = requests.post(API_ENDPOINT, json=raw_data)
response.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"\n  "http://www.w3.org/TR/html4/loose.dtd">\n<html>\n  <head>\n    <title>TypeError: Cannot handle this data type: (1, 1, 3), &lt;f4 // Werkzeug Debugger</title>\n    <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"\n        type="text/css">\n    <!-- We need to make sure this has a favicon so that the debugger does\n         not by accident trigger a request to /favicon.ico which might\n         change the application state. -->\n    <link rel="shortcut icon"\n        href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">\n    <script src="?__debugger__=yes&amp;cmd=resource&amp;f=jquery.js"></script>\n    <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>\n    <script type="text/javascript">\n      var TRACEBACK = 140148643355616,\n          CONSOLE_MODE = false,\n          EVALEX = true,\n          EVALEX_TRUSTED = false,\n          SECRET = "EvuwKJD8R4oN4H
# ...

# %%
import matplotlib.pyplot as plt
import cv2
img=cv2.imread(image_path)
plt.imshow(img)

# %%
from json import dumps
import base64
import requests
from fvcore.common.timer import Timer
image_path = '/home/yuanpu/chefCap/data/val/JPEGImages/'
image_path +='mq291b5748000327-113432.jpg'
API_ENDPOINT = "http://10.1.202.11:5000/kitchen"

with open(image_path, "rb") as imageFile:
    base64_bytes = base64.b64encode(imageFile.read())
base64_string = base64_bytes.decode('utf-8')
raw_data = {'IMG_BASE64': base64_string,'SCORE_THRES': 0.7}
t1=Timer()
response = requests.post(API_ENDPOINT, json=raw_data)
t1.pause()

print(json.loads(response.text),'\n',t1.seconds())
# Out:
# {'predictions': {'Nums': 1, 'Items': [{'box': [660.0618286132812, 532.1910400390625, 794.582275390625, 705.4365844726562], 'class': 'mask-head 88%', 'score': 0.8767344951629639}], 'Errors': 0}}
#  0.23320142296142876
